# %%
# DataFlair Iris Flower Classification
# Import Packages
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
columns = ['Sepal length', 'Sepal width', 'Petal length', 'Petal width', 'Class_labels']
# Load the data
df = pd.read_csv('/content/Iris (1).csv', names=columns)
df.head()
# Out:
#      Sepal length   Sepal width   Petal length   Petal width Class_labels
# Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9             3            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa

# %%
columns = ['Sepal length', 'Sepal width', 'Petal length', 'Petal width', 'Class_labels'] # As per the iris dataset information

# %%
df.head(150)
# Out:
#       Sepal length   Sepal width   Petal length   Petal width    Class_labels
# Id   SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 1              5.1           3.5            1.4           0.2     Iris-setosa
# 2              4.9             3            1.4           0.2     Iris-setosa
# 3              4.7           3.2            1.3           0.2     Iris-setosa
# 4              4.6           3.1            1.5           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.3            5.7           2.5  Iris-virginica
# 146            6.7             3            5.2           2.3  Iris-virginica
# 147            6.3           2.5              5           1.9  Iris-virginica
# 148            6.5             3            5.2             2  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.describe()
# Out:
#        Sepal length Sepal width Petal length Petal width Class_labels
# count           151         151          151         151          151
# unique           36          24           44          23            4
# top               5           3          1.5         0.2  Iris-setosa
# freq             10          26           14          28           50

# %%
df.describe()
# Out:
#        Sepal length Sepal width Petal length Petal width Class_labels
# count           151         151          151         151          151
# unique           36          24           44          23            4
# top             5.0         3.0          1.5         0.2  Iris-setosa
# freq             10          26           14          28           50

# %%
from platform import platform
sns.scatterplot(data=df, x='Sepal length', y='Sepal width', hue='Class_labels')
plt.show()

# %%
data=df.values
X=data[:,0:4]
Y=data[:,4]
print(X)
# Out:
# [['SepalLengthCm' 'SepalWidthCm' 'PetalLengthCm' 'PetalWidthCm']
#  ['5.1' '3.5' '1.4' '0.2']
#  ['4.9' '3' '1.4' '0.2']
#  ['4.7' '3.2' '1.3' '0.2']
#  ['4.6' '3.1' '1.5' '0.2']
#  ['5' '3.6' '1.4' '0.2']
#  ['5.4' '3.9' '1.7' '0.4']
#  ['4.6' '3.4' '1.4' '0.3']
#  ['5' '3.4' '1.5' '0.2']
#  ['4.4' '2.9' '1.4' '0.2']
#  ['4.9' '3.1' '1.5' '0.1']
#  ['5.4' '3.7' '1.5' '0.2']
#  ['4.8' '3.4' '1.6' '0.2']
#  ['4.8' '3' '1.4' '0.1']
#  ['4.3' '3' '1.1' '0.1']
#  ['5.8' '4' '1.2' '0.2']
#  ['5.7' '4.4' '1.5' '0.4']
#  ['5.4' '3.9' '1.3' '0.4']
#  ['5.1' '3.5' '1.4' '0.3']
#  ['5.7' '3.8' '1.7' '0.3']
#  ['5.1' '3.8' '1.5' '0.3']
#  ['5.4' '3.4' '1.7' '0.2']
#  ['5.1' '3.7' '1.5' '0.4']
#  ['4.6' '3.6' '1' '0.2']
#  ['5.1' '3.3' '1.7' '0.5']
#  ['4.8' '3.4' '1.9' '0.2']
#  ['5' '3' '1.6' '0.2']
#  ['5' '3.4' '1.6' '0.4']
#  ['5.2' '3.5' '1.5' '0.2']
#  ['5.2' '3.4' '1.4' '0.2']
#  ['4.7' '3.2' '1.6' '0.2']
#  ['4.8' '3.1' '1.6' '0.2']
#  ['5.4' '3.4' '1.5' '0.4']
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.2)
print(X_train)
# Out:
# [['5' '3.6' '1.4' '0.2']
#  ['6' '2.2' '5' '1.5']
#  ['SepalLengthCm' 'SepalWidthCm' 'PetalLengthCm' 'PetalWidthCm']
#  ['6.9' '3.1' '5.1' '2.3']
#  ['5.6' '3' '4.5' '1.5']
#  ['5.5' '2.5' '4' '1.3']
#  ['5.6' '2.9' '3.6' '1.3']
#  ['4.8' '3' '1.4' '0.3']
#  ['5.9' '3' '5.1' '1.8']
#  ['6.9' '3.2' '5.7' '2.3']
#  ['5.1' '3.5' '1.4' '0.2']
#  ['5.7' '2.8' '4.1' '1.3']
#  ['5' '2' '3.5' '1']
#  ['6.3' '3.3' '6' '2.5']
#  ['6' '2.9' '4.5' '1.5']
#  ['7.6' '3' '6.6' '2.1']
#  ['4.9' '3.1' '1.5' '0.1']
#  ['6.3' '2.8' '5.1' '1.5']
#  ['6.8' '2.8' '4.8' '1.4']
#  ['7.7' '3' '6.1' '2.3']
#  ['5.8' '4' '1.2' '0.2']
#  ['5' '3.5' '1.3' '0.3']
#  ['5.4' '3.7' '1.5' '0.2']
#  ['6.2' '2.2' '4.5' '1.5']
#  ['5' '3' '1.6' '0.2']
#  ['6.6' '2.9' '4.6' '1.3']
#  ['6.2' '2.9' '4.3' '1.3']
#  ['6.7' '3' '5.2' '2.3']
#  ['4.8' '3.1' '1.6' '0.2']
#  ['5.8' '2.6' '4' '1.2']
#  ['6.4' '2.8' '5.6' '2.1']
#  ['5.4' '3.4' '1.5' '0.4']
#  ['6' '3.4' '4.5' '1.6']
#  ['5.8' '2.7' '5.1' '1.9']
# ...

# %%
# Support vector machine algorithm
from sklearn.svm import SVC
svn = SVC()
svn.fit(X_train, y_train)
# Out:
# SVC()

# %%
# Load the data
# Skip the header row when reading the CSV file
df = pd.read_csv('/content/Iris (1).csv', names=columns, skiprows=1)

# ... (rest of your code) ...

# Extract features and target variable
# Assuming your features are in columns 0-3 and target in column 4
# If your data has a header row, adjust the column indices accordingly
data = df.values
X = data[:, 0:4].astype(float)  # Convert features to float explicitly
Y = data[:, 4]

# ... (rest of your code) ...

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import accuracy_score

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5, p=2, metric='minkowski')
knn.fit(X_train, y_train)

knn.score(X_test, y_test)
# Out:
# 0.9666666666666667

# %%
# Split the data to train and test dataset.
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
from sklearn.svm import SVC
svm = SVC(kernel='rbf', random_state=0, gamma=.10, C=1.0)
svm.fit(X_train, y_train)

svm.score(X_test, y_test)
# Out:
# 0.9666666666666667

# %%
X_new = np.array([[3, 2, 1, 0.2], [  4.9, 2.2, 3.8, 1.1 ], [  5.3, 2.5, 4.6, 1.9 ]])
#Prediction of the species from the input vector
prediction = svn.predict(X_new)
print("Prediction of Species: {}".format(prediction))
# Out:
# Prediction of Species: ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']
